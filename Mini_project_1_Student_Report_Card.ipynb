# %% [markdown]
# <a href="https://colab.research.google.com/github/14sindura2003-hue/PYTHON-/blob/main/Mini_project_1_Student_Report_Card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mini Project:
#
# Create a Student Report Card Program using:
#
# 1.List → store student names
#
# 2.Set → store subjects
#
# 3.Tuple → store student information (name, age)
#
# 4.Dictionary → store subject-wise marks
#
# Requirements:
#
# 1.Ask the user to enter:
#
# *Student name
#
# *Age
#
# *Number of subjects
#
# 2.For each subject:
#
# *Enter subject name
#
# *Enter marks
#
# 3.Store:
#
# *Name in a list
#
# *Subjects in a set
#
# *Student info in a tuple
#
# *Marks in a dictionary
#
# 4.Print a report card showing:
#
# *Name
#
# *Age
#
# *Subjects
#
# *Marks
#
# *Total marks
#
# *Average marks
#  code in python

# %%
# Student Report Card Program

# List to store student names
student_names = []

# Set to store subjects
subjects = set()

# Dictionary to store subject-wise marks
marks = {}

# Get student details
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
num_subjects = int(input("Enter Number of Subjects: "))

# Store name in list
student_names.append(name)

# Store student info in tuple
student_info = (name, age)

# Input subject names and marks
for i in range(num_subjects):
    subject = input(f"\nEnter Subject {i+1} Name: ")
    mark = int(input(f"Enter Marks in {subject}: "))

    subjects.add(subject)
    marks[subject] = mark

# Calculate total and average
total_marks = sum(marks.values())
average_marks = total_marks / num_subjects

# Display Report Card
print("\n========== STUDENT REPORT CARD ==========")
print("Student Name :", student_info[0])
print("Age          :", student_info[1])

print("\nSubjects:")
for subject in subjects:
    print(subject)

print("\nSubject-wise Marks:")
for subject, mark in marks.items():
    print(subject, ":", mark)

print("\nTotal Marks  :", total_marks)
print("Average Marks:", round(average_marks, 2))
# Out:
# Enter Student Name: sindura
# Enter Age: 22
# Enter Number of Subjects: 3
#
# Enter Subject 1 Name: phython
# Enter Marks in phython: 45
#
# Enter Subject 2 Name: english
# Enter Marks in english: 50
#
# Enter Subject 3 Name: java
# Enter Marks in java: 42
#
# ========== STUDENT REPORT CARD ==========
# Student Name : sindura
# Age          : 22
#
# Subjects:
# phython
# java
# english
#
# Subject-wise Marks:
# phython : 45
# english : 50
# java : 42
#
# Total Marks  : 137
# Average Marks: 45.67
