# %% [markdown]
# <a href="https://colab.research.google.com/github/14sindura2003-hue/PYTHON-/blob/main/TASK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# write a program on simple linear prediction given 'x' : predict y using y=2x+3

# %%
x = int(input("enter the value of x"))
y = 2*x + 3
print(y)
# Out:
# enter the value of x14
# 31

# %% [markdown]
# write a program on Threshold classification if temperature is greater than 30 it should print "hot" else "normal" take input and print result

# %%
tem = int(input("enter the temperature"))
if tem > 30:
    print("hot")
else:
    print("normal")
# Out:
# enter the temperature54
# hot

# %% [markdown]
# write a program to find the avg of 5 numbers

# %%
a = int(input("enter the value of a"))
b = int(input("enter the value of b"))
c = int(input("enter the value of c"))
d = int(input("enter the value of d"))
e = int(input("enter the value of e"))
avg = (a+b+c+d+e)/5
print(avg)
# Out:
# enter the value of a14
# enter the value of b8
# enter the value of c23
# enter the value of d28
# enter the value of e19
# 18.4

# %%
a = int(input("enter the value of a"))
b = int(input("enter the value of b"))
c = int(input("enter the value of c"))
d = int(input("enter the value of d"))
e = int(input("enter the value of e"))
for i in range(1,6):
  sum = 0
  sum = sum + i
print(sum)
# Out:
# enter the value of a5
# enter the value of b19
# enter the value of c23
# enter the value of d8
# enter the value of e19
# 5

# %% [markdown]
# Take a list with n no.of elements now append 100 digit

# %%
l=['1','2','3','5']
l.append('6')
print(l)
# Out:
# ['1', '2', '3', '5', '6']

# %% [markdown]
# Reverse the list

# %%
l = ["A","B","C","D"]
l.reverse()
print(l)
# Out:
# ['D', 'C', 'B', 'A']

# %% [markdown]
# Find the sum of the elements in the list

# %%
l = ['1','2','3','4']
t = 0
for i in l:
    t = t + int(i)
print(t)
# Out:
# 10

# %% [markdown]
# Find the min and max values in the list

# %%
l=['85','32','64','96']
print("minimum value is : ",min(l))
print("maximum value is : ",max(l))
# Out:
# minimum value is :  32
# maximum value is :  96

# %% [markdown]
# Check if 2 sets have common elements

# %%
l1 = ['1','2','3','4']
l2 = ['4','5','6','7']
L = set(l1).intersection(set(l2))
print(L)
# Out:
# {'4'}

# %% [markdown]
# remove duplcates from the list using set

# %%
l = [1, 2, 3, 2, 4, 5, 3, 6]
l = list(set(l))
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Count the number of unique chars in a string

# %%
s = 'sinnduuraa'
sets = set(s)
print(sets)
# Out:
# {'s', 'd', 'a', 'r', 'i', 'n', 'u'}
